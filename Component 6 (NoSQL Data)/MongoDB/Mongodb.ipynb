# %%
pip install pymongo
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/926.7 kB ? eta -:--:--
#    ---------------------------------------- 926.7/926.7 kB 8.5 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

#We connect to MongoDB
client = MongoClient("mongodb://localhost:27017")
db = client["AirQualityDB"]

#We then list out our sample station
station_data = {
    "station_id": "501",
    "Name": "Colston Avenue",
    "Latitude":51.4552693827,
    "Longitude":-2.59664882855,
    "Constituency": {
        "Constituency_ID": "4",
        "Name": "Bristol West"
    },
    "AirQualityMeasurement": [
        { 
            
            "Date_Time": "2019-04-29 23:00:00+00:00",
            "NOx": "122.25",
            "NO2": "49.25",
            "NO": "47.75",
            "PM10": "30.40",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "1",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": ""
        },
        { 
            
            "Date_Time": "2019-04-30 03:00:00+00:00",
            "NOx": "42.25",
            "NO2": "35.25",
            "NO": "4.5",
            "PM10": "20.75",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "2",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": ""
        },
        { 
            
            "Date_Time": "2019-05-01 06:00:00+00:00",
            "NOx": "82",
            "NO2": "48.5",
            "NO": "21.75",
            "PM10": "28.13",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "3",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": ""
        },
        { 
            
            "Date_Time": "2019-05-01 18:00:00+00:00",
            "NOx": "357.25",
            "NO2": "117.75",
            "NO": "156.5",
            "PM10": "27.70",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "4",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": ""
        },
        { 
            
            "Date_Time": "2019-05-02 14:00:00+00:00",
            "NOx": "194.5",
            "NO2": "73.25",
            "NO": "79.25",
            "PM10": "23.77",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "5",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": ""
        },
        {
            
            "Date_Time": "2019-05-02 17:00:00+00:00",
            "NOx": "236.25",
            "NO2": "89.5",
            "NO": "95.75",
            "PM10": "22.93",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "6",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "", 
            "SO2": ""
        },
        { 
            
            "Date_Time": "2019-05-03 02:00:00+00:00",
            "NOx": "63.25",
            "NO2": "36.5",
            "NO": "17.25",
            "PM10": "16.55",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "7",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": ""
        },
        { 
            
            "Date_Time": "2019-05-03 03:00:00+00:00",
            "NOx": "71",
            "NO2": "38",
            "NO": "21.25",
            "PM10": "16.08", 
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "8",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": ""
        },
        { 
            
            "Date_Time": "2019-05-03 07:00:00+00:00",
            "NOx": "376",
            "NO2": "92.75",
            "NO": "121", 
            "PM10": "18.38",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "9",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": ""
        },
        {
            
            "Date_Time": "2019-05-03 14:00:00+00:00",
            "NOx": "274.75",
            "NO2": "89",
            "NO": "121",
            "PM10": " 18.63",
            "O3": "",
            "Temperature": "",
            "ObjectId": "",
            "ObjectId2": "10",
            "NVPM10": "",
            "VPM10": "",
            "NVPM2.5": "",
            "PM2.5": "",
            "VPM2.5": "",
            "CO": "",
            "Pressure": "",
            "SO2": "",
        }
    ],
}


# Data import to MongoDB
db.stations.insert_one(station_data)

print("Data successfully inserted")
# Out:
# Data successful inserted
